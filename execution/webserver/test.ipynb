# %%
from __init__ import WebApp, FeedType
import time
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from __init__ import WebApp, FeedType
#       2 import time
#       3 from PIL import Image
#
# File c:\Users\Simon\Documents\projecten\paint-bot\src\webserver\__init__.py:15
#      11     target_feed = auto()
#      12     expected_feed = auto()
# ---> 15 class WebApp:
#      16     app = None
#      17     _thread = None
#
# File c:\Users\Simon\Documents\projecten\paint-bot\src\webserver\__init__.py:21, in WebApp()
#      19 _fan_mode = False
#      20 _slots = 2
# ---> 21 _feeds = {slot: FeedType.camera_feed for slot in _slots}
#      22 _images = {feed_type: None for feed_type in FeedType}
#      23 _image_versions = {feed_type: 0 for feed_type in FeedType}
#
# TypeError: 'int' object is not iterable

# %%
WebApp.init(on_fan_change=lambda mode:print(mode))
WebApp.start()
# Out:
# <Thread(Thread-3 (_run), started daemon 13616)>
#  * Serving Flask app '__init__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jul/2026 14:38:19] "GET /feed-image/camera_feed?t=1783946297688 HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2026 14:38:20] "GET /feed-image/camera_feed?t=1783946300316 HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2026 14:38:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2026 14:38:20] "GET /feed-image/camera_feed?v=1 HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2026 14:38:21] "GET /feed-image/camera_feed?t=1783946301856 HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2026 14:38:22] "GET /feed-image/camera_feed?t=1783946302869 HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jul/2026 14:38:23] "GET /feed-image/camera_feed?t=1783946303865 HTTP/1.1" 200 -
# ...

# %%
# 1. Define the image dimensions and color
# Formats accepted: "red", "#FF0000", or an RGB tuple (255, 0, 0)
width, height = 640, 400
color = (120, 230, 50)  # Blue

# 2. Create the solid color image
img = Image.new("RGB", (width, height), color)

# Your loop
while True:
    # 3. Pass the PIL image object to your WebApp
    WebApp.set_feed_image(FeedType.camera_feed, img)
    
    print("Sleeping")
    time.sleep(5)
    print("Changing")
# Out:
# Sleeping
# Changing
# Sleeping
# Changing
# Sleeping
# Changing
# Sleeping
# Changing
# Sleeping
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      12 WebApp.set_feed_image(FeedType.camera_feed, img)
#      14 print("Sleeping")
# ---> 15 time.sleep(5)
#      16 print("Changing")
#
# KeyboardInterrupt:
