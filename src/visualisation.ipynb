# %%
from visualisation import visualize_stroke_sequence
from datatypes import StrokePath, StrokeSequence

# %%
my_stroke_sequence = StrokeSequence.load_from_json("data/resized_stroke_sequence.json")
my_stroke_sequence.unit = "steps"

# %%
visualize_stroke_sequence(my_stroke_sequence)
# Out:
# <PIL.Image.Image image mode=RGB size=343x388>

# %%
visualize_stroke_sequence(my_stroke_sequence, max_count=0)
# Out:
# <PIL.Image.Image image mode=RGB size=343x388>
